# %%
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('TSLA_sentiment.csv')
df.head()
# Out:
#    Unnamed: 0       index  subj_score  simi_score  vader_score
# 0           0  2021-08-30    0.220619    0.131578     0.468430
# 1           1  2021-08-31    0.298812    0.314914     0.682320
# 2           2  2021-09-01    0.380090    0.822681     0.877310
# 3           3  2021-09-02    0.228122    0.167491     0.574075
# 4           4  2021-09-03    0.231336    0.112461     0.515755

# %%
df2 = df.drop(columns = ['Unnamed: 0'])

# %%
df2.set_index('index', inplace = True)
df2.plot()
# Out:
# <AxesSubplot:xlabel='index'>
